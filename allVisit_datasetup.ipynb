# %%
import numpy as np
import pandas as pd
from astropy.io import fits

# %%
visit_hdus = fits.open('allVisit-r12-l33.fits')

# print(visit_hdus.info())
# Out:
# Filename: allVisit-r12-l33.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      13   ()
#   1                1 BinTableHDU    209   1778792R x 96C   [57A, 3A, 18A, 47A, 46A, I, 13A, J, 6A, 14A, 16A, 18A, I, D, D, D, D, E, E, E, E, E, E, D, D, J, J, J, 192A, E, J, 74A, 23A, D, E, I, E, E, E, E, E, E, E, E, E, E, E, 18A, I, E, E, E, E, E, E, E, E, E, J, J, J, I, I, E, E, E, E, 47A, 14A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 17A, E, E, I, I, E, E, 20A]
#   2                1 ImageHDU         6   (360,)   int32
# None

# %%
visit_header = visit_hdus[1].header
visit_data = visit_hdus[1].data

visit_hdus.close()

# print(visit_header)

# %%
all_targets = list(visit_data['TARGET_ID'])
all_mjd = list(visit_data['MJD'])
all_obsvhelio = list(visit_data['OBSVHELIO']) # Heliocentric relative RV from 'observed spectrum template matching'
all_plates = list(visit_data['PLATE'])

# %%
for i, s in enumerate(all_plates):
    all_plates[i] = s.strip()
    
# print(all_plates[:7])
# Out:
# ['Bestars', 'Bestars', 'calibration', 'calibration', 'calibration', '7545', '7545']

# %%
all_data = [all_targets, all_plates, all_mjd, all_obsvhelio]

df = pd.DataFrame(all_data).transpose()
df.columns = ['Target ID', 'Plate ID', 'MJD', 'OBSVHELIO (km/s)']

# %%
df.head(10)
# Out:
#                                Target ID     Plate ID    MJD OBSVHELIO (km/s)
# 0                       apo1m.1.Bestars.      Bestars  58017         -523.166
# 1                       apo1m.1.Bestars.      Bestars  58022         -526.084
# 2              apo1m.1.calibration.VESTA  calibration  56398          25.5533
# 3              apo1m.1.calibration.VESTA  calibration  56778          10.5618
# 4                   apo1m.1.calibration.  calibration  57743         -36.2044
# 5  apo25m.5046.120+12.2M00000002+7417074         7545  56933          -51.673
# 6  apo25m.5046.120+12.2M00000002+7417074         7545  56936         -51.6342
# 7  apo25m.5046.120+12.2M00000002+7417074         7545  56971         -51.8788
# 8  apo25m.5071.060-75.2M00000019-1924498         7917  57293           18.841
# 9  apo25m.5071.060-75.2M00000019-1924498         7917  58037           19.174

# %%
list(df['Target ID'].value_counts())
# Out:
# [40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  34,
#  34,
#  34,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  ...]

# %%
from collections import Counter

# %%
def removeElements(lst, k):
    counted = Counter(lst)
    
    temp_lst = []
    for el in counted:
        if counted[el] < k:
            temp_lst.append(el)
            
    res_lst = []
    for el in lst:
        if el not in temp_lst:
            res_lst.append(el)
    
    return(res_lst)

# %%
# removeElements(all_targets, 20)

# %%
target_count = Counter(all_targets)

# %%
filtered_targets = []

# %%
for tc in target_count:
    if target_count[tc] > 19:
        filtered_targets.append(tc)

# %%
filtered_targets
# Out:
# ['apo25m.4205.PAL1.2M03033027+7944165',
#  'apo25m.4205.PAL1.2M03060474+8013408',
#  'apo25m.4205.PAL1.2M03062146+7929484',
#  'apo25m.4205.PAL1.2M03062526+7950267',
#  'apo25m.4205.PAL1.2M03070369+7933134',
#  'apo25m.4205.PAL1.2M03075883+7917311',
#  'apo25m.4205.PAL1.2M03080601+7950502',
#  'apo25m.4205.PAL1.2M03090670+7900147',
#  'apo25m.4205.PAL1.2M03092335+8028056',
#  'apo25m.4205.PAL1.2M03095856+8017486',
#  'apo25m.4205.PAL1.2M03102873+7959033',
#  'apo25m.4205.PAL1.2M03110749+8017101',
#  'apo25m.4205.PAL1.2M03111983+7946105',
#  'apo25m.4205.PAL1.2M03122666+7925037',
#  'apo25m.4205.PAL1.2M03123190+8018137',
#  'apo25m.4205.PAL1.2M03123498+8008273',
#  'apo25m.4205.PAL1.2M03125124+7936187',
#  'apo25m.4205.PAL1.2M03125732+7849280',
#  'apo25m.4205.PAL1.2M03125915+8025555',
#  'apo25m.4205.PAL1.2M03143271+7836060',
#  'apo25m.4205.PAL1.2M03155046+7850377',
#  'apo25m.4205.PAL1.2M03161090+7916531',
#  'apo25m.4205.PAL1.2M03172162+7852302',
#  'apo25m.4205.PAL1.2M03175829+7840253',
#  'apo25m.4205.PAL1.2M03185660+7934083',
#  'apo25m.4205.PAL1.2M03192262+7836486',
#  'apo25m.4205.PAL1.2M03205400+7944083',
#  'apo25m.4205.PAL1.2M03224269+7932066',
#  'apo25m.4205.PAL1.2M03232876+7905298',
#  'apo25m.4205.PAL1.2M03233653+7854054',
#  'apo25m.4205.PAL1.2M03234908+8037481',
#  'apo25m.4205.PAL1.2M03241388+7931507',
#  'apo25m.4205.PAL1.2M03243358+8052012',
#  'apo25m.4205.PAL1.2M03243919+8032046',
#  'apo25m.4205.PAL1.2M03244421+7830452',
#  'apo25m.4205.PAL1.2M03250867+7947271',
#  'apo25m.4205.PAL1.2M03252050+7830157',
#  'apo25m.4205.PAL1.2M03260983+7917170',
#  'apo25m.4205.PAL1.2M03262508+8007344',
#  'apo25m.4205.PAL1.2M03264599+7954011',
#  'apo25m.4205.PAL1.2M03275079+8013204',
#  'apo25m.4205.PAL1.2M03282868+7944433',
#  'apo25m.4205.PAL1.2M03283958+7816374',
#  'apo25m.4205.PAL1.2M03285154+7907510',
#  'apo25m.4205.PAL1.2M03293869+7823520',
#  'apo25m.4205.PAL1.2M03294789+7857241',
#  'apo25m.4205.PAL1.2M03300833+8014116',
#  'apo25m.4205.PAL1.2M03302061+7941272',
#  'apo25m.4205.PAL1.2M03311752+7935004',
#  'apo25m.4205.PAL1.2M03313107+7924571',
#  'apo25m.4205.PAL1.2M03313300+7852496',
#  'apo25m.4205.PAL1.2M03320943+7901322',
#  'apo25m.4205.PAL1.2M03320976+8016167',
#  'apo25m.4205.PAL1.2M03322027+7921348',
#  'apo25m.4205.PAL1.2M03322141+8045097',
#  'apo25m.4205.PAL1.2M03325390+8047161',
#  'apo25m.4205.PAL1.2M03325760+7826454',
#  'apo25m.4205.PAL1.2M03332183+7935382',
#  'apo25m.4205.PAL1.2M03332960+7934162',
#  'apo25m.4205.PAL1.2M03340244+8050051',
#  'apo25m.4205.PAL1.2M03341339+8042195',
#  'apo25m.4205.PAL1.2M03343198+7913459',
#  'apo25m.4205.PAL1.2M03343857+7935032',
#  'apo25m.4205.PAL1.2M03344917+7927277',
#  'apo25m.4205.PAL1.2M03351056+7920382',
#  'apo25m.4205.PAL1.2M03351106+7832501',
#  'apo25m.4205.PAL1.2M03354418+7936186',
#  'apo25m.4205.PAL1.2M03354469+7918246',
#  'apo25m.4205.PAL1.2M03354956+7832393',
#  'apo25m.4205.PAL1.2M03354987+8045206',
#  'apo25m.4205.PAL1.2M03360098+8032080',
#  'apo25m.4205.PAL1.2M03362177+8052598',
#  'apo25m.4205.PAL1.2M03365401+7939075',
#  'apo25m.4205.PAL1.2M03370791+7825182',
#  'apo25m.4205.PAL1.2M03371679+7929074',
#  'apo25m.4205.PAL1.2M03374529+7918131',
#  'apo25m.4205.PAL1.2M03375220+8016542',
#  'apo25m.4205.PAL1.2M03380555+7825444',
#  'apo25m.4205.PAL1.2M03384453+8016228',
#  'apo25m.4205.PAL1.2M03391964+8059444',
#  'apo25m.4205.PAL1.2M03392352+8011555',
#  'apo25m.4205.PAL1.2M03394236+7909226',
#  'apo25m.4205.PAL1.2M03394389+7844155',
#  'apo25m.4205.PAL1.2M03400270+8034123',
#  'apo25m.4205.PAL1.2M03404976+7946125',
#  'apo25m.4205.PAL1.2M03405748+8034503',
#  'apo25m.4205.PAL1.2M03410042+8022058',
#  'apo25m.4205.PAL1.2M03410800+7944122',
#  'apo25m.4205.PAL1.2M03412497+7818326',
#  'apo25m.4205.PAL1.2M03414366+7948371',
#  'apo25m.4205.PAL1.2M03420866+7909094',
#  'apo25m.4205.PAL1.2M03420876+7845421',
#  'apo25m.4205.PAL1.2M03421595+7931453',
#  'apo25m.4205.PAL1.2M03422851+7828493',
#  'apo25m.4205.PAL1.2M03430646+8007367',
#  'apo25m.4205.PAL1.2M03443721+7819174',
#  'apo25m.4205.PAL1.2M03444598+8026588',
#  'apo25m.4205.PAL1.2M03460835+8013551',
#  'apo25m.4205.PAL1.2M03462777+8019333',
#  'apo25m.4205.PAL1.2M03464631+8050371',
#  'apo25m.4205.PAL1.2M03470946+7922564',
#  'apo25m.4205.PAL1.2M03473428+7842304',
#  'apo25m.4205.PAL1.2M03481809+7931234',
#  'apo25m.4205.PAL1.2M03490880+7934130',
#  'apo25m.4205.PAL1.2M03491045+7935481',
#  'apo25m.4205.PAL1.2M03494426+8027289',
#  'apo25m.4205.PAL1.2M03494838+7908571',
#  'apo25m.4205.PAL1.2M03504296+7819442',
#  'apo25m.4205.PAL1.2M03504320+7917561',
#  'apo25m.4205.PAL1.2M03504584+8026223',
#  'apo25m.4205.PAL1.2M03510670+7920180',
#  'apo25m.4205.PAL1.2M03520833+7925569',
#  'apo25m.4205.PAL1.2M03524186+7850481',
#  'apo25m.4205.PAL1.2M03542688+8021485',
#  'apo25m.4205.PAL1.2M03543824+7859239',
#  'apo25m.4205.PAL1.2M03553407+7906559',
#  'apo25m.4205.PAL1.2M03564953+7933004',
#  'apo25m.4205.PAL1.2M03570863+7928324',
#  'apo25m.4205.PAL1.2M03573478+7910429',
#  'apo25m.4205.PAL1.2M03574526+7918223',
#  'apo25m.4205.PAL1.2M03580856+7941254',
#  'apo25m.4205.PAL1.2M04000790+8012317',
#  'apo25m.4205.PAL1.2M04003598+7932439',
#  'apo25m.4205.PAL1.2M04021546+7908284',
#  'apo25m.4205.PAL1.2M04033826+7935087',
#  'apo25m.4205.PAL1.2M04042433+7853040',
#  'apo25m.4205.PAL1.2M04043164+8011002',
#  'apo25m.4205.PAL1.2M04050193+7906395',
#  'apo25m.4205.PAL1.2M04052460+7929500',
#  'apo25m.4205.PAL1.2M04055992+7947125',
#  'apo25m.4205.PAL1.2M04060410+8016436',
#  'apo25m.4205.PAL1.2M04063732+7916012',
#  'apo25m.4205.PAL1.2M04065128+7943403',
#  'apo25m.4205.PAL1.2M04084944+7945504',
#  'apo25m.5114.SGRT-1.2M05133961+2432523',
#  'apo25m.5114.SGRT-1.2M05134946+2427371',
#  'apo25m.5114.SGRT-1.2M05140155+2442356',
#  'apo25m.5114.SGRT-1.2M05140298+2451030',
#  'apo25m.5114.SGRT-1.2M05140311+2457006',
#  'apo25m.5114.SGRT-1.2M05140368+2446333',
#  'apo25m.5114.SGRT-1.2M05140823+2457264',
#  'apo25m.5114.SGRT-1.2M05141020+2424187',
#  'apo25m.5114.SGRT-1.2M05141267+2416493',
#  'apo25m.5114.SGRT-1.2M05141719+2423394',
#  'apo25m.5114.SGRT-1.2M05142196+2427587',
#  'apo25m.5114.SGRT-1.2M05142218+2515316',
#  'apo25m.5114.SGRT-1.2M05142386+2430402',
#  'apo25m.5114.SGRT-1.2M05142436+2446298',
#  'apo25m.5114.SGRT-1.2M05142711+2459012',
#  'apo25m.5114.SGRT-1.2M05143125+2357517',
#  'apo25m.5114.SGRT-1.2M05143266+2423057',
#  'apo25m.5114.SGRT-1.2M05143394+2436324',
#  'apo25m.5114.SGRT-1.2M05143594+2453505',
#  'apo25m.5114.SGRT-1.2M05145393+2513244',
#  'apo25m.5114.SGRT-1.2M05145590+2453356',
#  'apo25m.5114.SGRT-1.2M05145994+2525212',
#  'apo25m.5114.SGRT-1.2M05150150+2333596',
#  'apo25m.5114.SGRT-1.2M05150669+2436567',
#  'apo25m.5114.SGRT-1.2M05150768+2431188',
#  'apo25m.5114.SGRT-1.2M05151311+2332088',
#  'apo25m.5114.SGRT-1.2M05152109+2338513',
#  'apo25m.5114.SGRT-1.2M05152409+2345020',
#  'apo25m.5114.SGRT-1.2M05152856+2525467',
#  'apo25m.5114.SGRT-1.2M05153401+2329426',
#  'apo25m.5114.SGRT-1.2M05153576+2359487',
#  'apo25m.5114.SGRT-1.2M05154092+2326137',
#  'apo25m.5114.SGRT-1.2M05154444+2419222',
#  'apo25m.5114.SGRT-1.2M05154842+2505468',
#  'apo25m.5114.SGRT-1.2M05155005+2333438',
#  'apo25m.5114.SGRT-1.2M05155196+2450235',
#  'apo25m.5114.SGRT-1.2M05155356+2358546',
#  'apo25m.5114.SGRT-1.2M05155554+2331584',
#  'apo25m.5114.SGRT-1.2M05155639+2414045',
#  'apo25m.5114.SGRT-1.2M05155688+2446380',
#  'apo25m.5114.SGRT-1.2M05155696+2346499',
#  'apo25m.5114.SGRT-1.2M05160072+2459219',
#  'apo25m.5114.SGRT-1.2M05160373+2450348',
#  'apo25m.5114.SGRT-1.2M05160474+2443207',
#  'apo25m.5114.SGRT-1.2M05160855+2402474',
#  'apo25m.5114.SGRT-1.2M05160975+2501418',
#  'apo25m.5114.SGRT-1.2M05161413+2414487',
#  'apo25m.5114.SGRT-1.2M05161625+2355236',
#  'apo25m.5114.SGRT-1.2M05161663+2430165',
#  'apo25m.5114.SGRT-1.2M05162840+2528546',
#  'apo25m.5114.SGRT-1.2M05162944+2342549',
#  'apo25m.5114.SGRT-1.2M05163795+2415162',
#  'apo25m.5114.SGRT-1.2M05164512+2432464',
#  'apo25m.5114.SGRT-1.2M05164658+2319382',
#  'apo25m.5114.SGRT-1.2M05164786+2523160',
#  'apo25m.5114.SGRT-1.2M05164941+2451000',
#  'apo25m.5114.SGRT-1.2M05165506+2534457',
#  'apo25m.5114.SGRT-1.2M05165815+2406084',
#  'apo25m.5114.SGRT-1.2M05165888+2507025',
#  'apo25m.5114.SGRT-1.2M05170385+2420529',
#  'apo25m.5114.SGRT-1.2M05170415+2448148',
#  'apo25m.5114.SGRT-1.2M05170455+2440432',
#  'apo25m.5114.SGRT-1.2M05170456+2514022',
#  'apo25m.5114.SGRT-1.2M05170471+2332013',
#  'apo25m.5114.SGRT-1.2M05170870+2517041',
#  'apo25m.5114.SGRT-1.2M05170946+2457178',
#  'apo25m.5114.SGRT-1.2M05171225+2358379',
#  'apo25m.5114.SGRT-1.2M05171851+2518219',
#  'apo25m.5114.SGRT-1.2M05172320+2507243',
#  'apo25m.5114.SGRT-1.2M05172611+2333480',
#  'apo25m.5114.SGRT-1.2M05173140+2349059',
#  'apo25m.5114.SGRT-1.2M05173513+2404258',
#  'apo25m.5114.SGRT-1.2M05173611+2359039',
#  'apo25m.5114.SGRT-1.2M05173739+2542398',
#  'apo25m.5114.SGRT-1.2M05173777+2432004',
#  'apo25m.5114.SGRT-1.2M05173971+2537023',
#  'apo25m.5114.SGRT-1.2M05174611+2423414',
#  'apo25m.5114.SGRT-1.2M05174703+2357048',
#  'apo25m.5114.SGRT-1.2M05174993+2354143',
#  'apo25m.5114.SGRT-1.2M05175034+2410367',
#  'apo25m.5114.SGRT-1.2M05175338+2436206',
#  'apo25m.5114.SGRT-1.2M05175750+2500268',
#  'apo25m.5114.SGRT-1.2M05180336+2501145',
#  'apo25m.5114.SGRT-1.2M05180383+2504340',
#  'apo25m.5114.SGRT-1.2M05180586+2543169',
#  'apo25m.5114.SGRT-1.2M05180911+2421151',
#  'apo25m.5114.SGRT-1.2M05181188+2507335',
#  'apo25m.5114.SGRT-1.2M05181194+2313541',
#  'apo25m.5114.SGRT-1.2M05181584+2408210',
#  'apo25m.5114.SGRT-1.2M05181644+2311001',
#  'apo25m.5114.SGRT-1.2M05182160+2329307',
#  'apo25m.5114.SGRT-1.2M05182314+2448368',
#  'apo25m.5114.SGRT-1.2M05182497+2326517',
#  'apo25m.5114.SGRT-1.2M05182874+2403296',
#  'apo25m.5114.SGRT-1.2M05183431+2358567',
#  'apo25m.5114.SGRT-1.2M05184160+2315384',
#  'apo25m.5114.SGRT-1.2M05184361+2322453',
#  'apo25m.5114.SGRT-1.2M05184847+2521071',
#  'apo25m.5114.SGRT-1.2M05184959+2556407',
#  'apo25m.5114.SGRT-1.2M05184984+2418071',
#  'apo25m.5114.SGRT-1.2M05185458+2441051',
#  'apo25m.5114.SGRT-1.2M05185930+2510578',
#  'apo25m.5114.SGRT-1.2M05190461+2303316',
#  'apo25m.5114.SGRT-1.2M05190707+2437379',
#  'apo25m.5114.SGRT-1.2M05190872+2518399',
#  'apo25m.5114.SGRT-1.2M05191593+2457476',
#  'apo25m.5114.SGRT-1.2M05191818+2509531',
#  'apo25m.5114.SGRT-1.2M05192247+2407193',
#  'apo25m.5114.SGRT-1.2M05192288+2457493',
#  'apo25m.5114.SGRT-1.2M05192642+2359447',
#  'apo25m.5114.SGRT-1.2M05192653+2305196',
#  'apo25m.5114.SGRT-1.2M05192846+2516016',
#  'apo25m.5114.SGRT-1.2M05192858+2356272',
#  'apo25m.5114.SGRT-1.2M05192908+2514389',
#  'apo25m.5114.SGRT-1.2M05192940+2510417',
#  'apo25m.5114.SGRT-1.2M05193252+2520106',
#  'apo25m.5114.SGRT-1.2M05193866+2523567',
#  'apo25m.5114.SGRT-1.2M05193870+2553272',
#  'apo25m.5114.SGRT-1.2M05193912+2410060',
#  'apo25m.5114.SGRT-1.2M05194207+2500589',
#  'apo25m.5114.SGRT-1.2M05194606+2458576',
#  'apo25m.5114.SGRT-1.2M05195243+2342202',
#  'apo25m.5114.SGRT-1.2M05195697+2410307',
#  'apo25m.5114.SGRT-1.2M05200269+2548507',
#  'apo25m.5114.SGRT-1.2M05200390+2525536',
#  'apo25m.5114.SGRT-1.2M05200620+2509149',
#  'apo25m.5114.SGRT-1.2M05201083+2500577',
#  'apo25m.5114.SGRT-1.2M05201197+2417083',
#  'apo25m.5114.SGRT-1.2M05201798+2510158',
#  'apo25m.5114.SGRT-1.2M05201875+2403029',
#  'apo25m.5114.SGRT-1.2M05201883+2530516',
#  'apo25m.5114.SGRT-1.2M05202254+2454117',
#  'apo25m.5114.SGRT-1.2M05202564+2346412',
#  'apo25m.5114.SGRT-1.2M05202565+2440105',
#  'apo25m.5114.SGRT-1.2M05202608+2426486',
#  'apo25m.5114.SGRT-1.2M05202649+2430541',
#  'apo25m.5114.SGRT-1.2M05202711+2305565',
#  'apo25m.5114.SGRT-1.2M05203047+2317457',
#  'apo25m.5114.SGRT-1.2M05203067+2329071',
#  'apo25m.5114.SGRT-1.2M05203843+2347454',
#  'apo25m.5114.SGRT-1.2M05203896+2504009',
#  'apo25m.5114.SGRT-1.2M05204398+2422591',
#  'apo25m.5114.SGRT-1.2M05204744+2536230',
#  'apo25m.5114.SGRT-1.2M05204754+2419581',
#  'apo25m.5114.SGRT-1.2M05205365+2408115',
#  'apo25m.5114.SGRT-1.2M05205426+2455332',
#  'apo25m.5114.SGRT-1.2M05205987+2338496',
#  'apo25m.5114.SGRT-1.2M05210235+2419529',
#  'apo25m.5114.SGRT-1.2M05210598+2538117',
#  'apo25m.5114.SGRT-1.2M05211236+2359472',
#  'apo25m.5114.SGRT-1.2M05212062+2402082',
#  'apo25m.5114.SGRT-1.2M05212068+2448101',
#  'apo25m.5114.SGRT-1.2M05212076+2329362',
#  'apo25m.5114.SGRT-1.2M05212390+2424454',
#  'apo25m.5114.SGRT-1.2M05212404+2506433',
#  'apo25m.5114.SGRT-1.2M05212457+2531338',
#  'apo25m.5114.SGRT-1.2M05212511+2358317',
#  'apo25m.5114.SGRT-1.2M05212691+2554154',
#  'apo25m.5114.SGRT-1.2M05213085+2320182',
#  'apo25m.5114.SGRT-1.2M05213459+2321426',
#  'apo25m.5114.SGRT-1.2M05213514+2511330',
#  'apo25m.5114.SGRT-1.2M05213623+2520354',
#  'apo25m.5114.SGRT-1.2M05213691+2320286',
#  'apo25m.5114.SGRT-1.2M05214477+2310449',
#  'apo25m.5114.SGRT-1.2M05214660+2401166',
#  'apo25m.5114.SGRT-1.2M05214699+2325100',
#  'apo25m.5114.SGRT-1.2M05214706+2507395',
#  'apo25m.5114.SGRT-1.2M05214898+2432476',
#  'apo25m.5114.SGRT-1.2M05215155+2346492',
#  'apo25m.5114.SGRT-1.2M05215218+2508083',
#  'apo25m.5114.SGRT-1.2M05215398+2516257',
#  'apo25m.5114.SGRT-1.2M05215580+2313122',
#  'apo25m.5114.SGRT-1.2M05215583+2408436',
#  'apo25m.5114.SGRT-1.2M05215602+2431249',
#  'apo25m.5114.SGRT-1.2M05215756+2332205',
#  'apo25m.5114.SGRT-1.2M05215823+2403325',
#  'apo25m.5114.SGRT-1.2M05215834+2446201',
#  'apo25m.5114.SGRT-1.2M05215971+2316363',
#  'apo25m.5114.SGRT-1.2M05220188+2536167',
#  'apo25m.5114.SGRT-1.2M05220326+2502217',
#  'apo25m.5114.SGRT-1.2M05220343+2328509',
#  'apo25m.5114.SGRT-1.2M05220371+2506095',
#  'apo25m.5114.SGRT-1.2M05220581+2545161',
#  'apo25m.5114.SGRT-1.2M05221639+2551501',
#  'apo25m.5114.SGRT-1.2M05221982+2413518',
#  'apo25m.5114.SGRT-1.2M05222327+2324202',
#  'apo25m.5114.SGRT-1.2M05222420+2427415',
#  'apo25m.5114.SGRT-1.2M05222960+2448276',
#  'apo25m.5114.SGRT-1.2M05222992+2426215',
#  'apo25m.5114.SGRT-1.2M05223309+2359162',
#  'apo25m.5114.SGRT-1.2M05223311+2314582',
#  'apo25m.5114.SGRT-1.2M05224235+2533261',
#  'apo25m.5114.SGRT-1.2M05225035+2536263',
#  'apo25m.5114.SGRT-1.2M05225601+2426291',
#  'apo25m.5114.SGRT-1.2M05230139+2421569',
#  'apo25m.5114.SGRT-1.2M05230202+2539212',
#  'apo25m.5114.SGRT-1.2M05230414+2425341',
#  'apo25m.5114.SGRT-1.2M05230798+2353087',
#  'apo25m.5114.SGRT-1.2M05230953+2518320',
#  'apo25m.5114.SGRT-1.2M05231190+2515336',
#  'apo25m.5114.SGRT-1.2M05231455+2332226',
#  'apo25m.5114.SGRT-1.2M05231809+2408243',
#  'apo25m.5114.SGRT-1.2M05232396+2319587',
#  'apo25m.5114.SGRT-1.2M05233177+2341328',
#  'apo25m.5114.SGRT-1.2M05233258+2523004',
#  'apo25m.5114.SGRT-1.2M05233633+2457318',
#  'apo25m.5114.SGRT-1.2M05233756+2331550',
#  'apo25m.5114.SGRT-1.2M05233801+2513507',
#  'apo25m.5114.SGRT-1.2M05233814+2526490',
#  'apo25m.5114.SGRT-1.2M05233899+2534528',
#  'apo25m.5114.SGRT-1.2M05233964+2338213',
#  'apo25m.5114.SGRT-1.2M05234448+2405194',
#  'apo25m.5114.SGRT-1.2M05234856+2401212',
#  'apo25m.5114.SGRT-1.2M05235790+2440075',
#  'apo25m.5114.SGRT-1.2M05235883+2438510',
#  'apo25m.5114.SGRT-1.2M05241091+2330087',
#  'apo25m.5114.SGRT-1.2M05241626+2323583',
#  'apo25m.5114.SGRT-1.2M05242251+2445541',
#  'apo25m.5114.SGRT-1.2M05242304+2435328',
#  'apo25m.5114.SGRT-1.2M05243460+2451504',
#  'apo25m.5114.SGRT-1.2M05243837+2443339',
#  'apo25m.5114.SGRT-1.2M05244258+2508327',
#  'apo25m.5114.SGRT-1.2M05244471+2447422',
#  'apo25m.5114.SGRT-1.2M05245076+2444238',
#  'apo25m.5114.SGRT-1.2M05250467+2355171',
#  'apo25m.5114.SGRT-1.2M05251089+2521073',
#  'apo25m.5114.SGRT-1.2M05251497+2354230',
#  'apo25m.5114.SGRT-1.2M05252229+2421085',
#  'apo25m.5114.SGRT-1.2M05253190+2438081',
#  'apo25m.5114.SGRT-1.2M05255351+2421523',
#  'apo25m.5114.SGRT-1.2M05255933+2415527',
#  'apo25m.5114.SGRT-1.2M05260373+2409387',
#  'apo25m.5114.SGRT-1.2M05261382+2436418',
#  'apo25m.5114.SGRT-1.2M05261550+2404454',
#  'apo25m.5246.150+30.2M07300876+6618366',
#  'apo25m.5246.150+30.2M07301327+6604035',
#  'apo25m.5246.150+30.2M07302512+6606197',
#  'apo25m.5246.150+30.2M07302547+6549114',
#  'apo25m.5246.150+30.2M07302928+6616442',
#  'apo25m.5246.150+30.2M07310061+6631117',
#  'apo25m.5246.150+30.2M07312989+6615010',
#  'apo25m.5246.150+30.2M07321941+6539071',
#  'apo25m.5246.150+30.2M07322284+6639017',
#  'apo25m.5246.150+30.2M07325706+6532450',
#  'apo25m.5246.150+30.2M07330886+6558162',
#  'apo25m.5246.150+30.2M07332083+6515122',
#  'apo25m.5246.150+30.2M07333184+6515566',
#  'apo25m.5246.150+30.2M07335184+6700372',
#  'apo25m.5246.150+30.2M07343470+6615553',
#  'apo25m.5246.150+30.2M07344658+6548155',
#  'apo25m.5246.150+30.2M07345461+6625169',
#  'apo25m.5246.150+30.2M07350917+6540252',
#  'apo25m.5246.150+30.2M07352930+6609248',
#  'apo25m.5246.150+30.2M07354382+6601053',
#  'apo25m.5246.150+30.2M07360529+6621141',
#  'apo25m.5246.150+30.2M07361274+6558249',
#  'apo25m.5246.150+30.2M07362076+6549474',
#  'apo25m.5246.150+30.2M07364435+6654100',
#  'apo25m.5246.150+30.2M07364689+6620376',
#  'apo25m.5246.150+30.2M07371256+6710044',
#  'apo25m.5246.150+30.2M07371543+6646520',
#  'apo25m.5246.150+30.2M07372536+6723086',
#  'apo25m.5246.150+30.2M07372574+6706367',
#  'apo25m.5246.150+30.2M07372920+6547457',
#  'apo25m.5246.150+30.2M07373186+6538468',
#  'apo25m.5246.150+30.2M07373351+6703497',
#  'apo25m.5246.150+30.2M07373526+6456440',
#  'apo25m.5246.150+30.2M07373790+6644216',
#  'apo25m.5246.150+30.2M07373879+6715525',
#  'apo25m.5246.150+30.2M07374232+6629309',
#  'apo25m.5246.150+30.2M07374339+6608528',
#  'apo25m.5246.150+30.2M07374484+6559501',
#  'apo25m.5246.150+30.2M07374551+6543034',
#  'apo25m.5246.150+30.2M07374582+6706194',
#  'apo25m.5246.150+30.2M07374739+6656581',
#  'apo25m.5246.150+30.2M07374812+6616399',
#  'apo25m.5246.150+30.2M07375054+6448158',
#  'apo25m.5246.150+30.2M07375221+6603186',
#  'apo25m.5246.150+30.2M07375455+6617460',
#  'apo25m.5246.150+30.2M07375506+6552086',
#  'apo25m.5246.150+30.2M07375789+6526369',
#  'apo25m.5246.150+30.2M07375851+6615549',
#  'apo25m.5246.150+30.2M07375864+6619455',
#  'apo25m.5246.150+30.2M07375868+6529085',
#  'apo25m.5246.150+30.2M07375916+6722076',
#  'apo25m.5246.150+30.2M07375957+6544455',
#  'apo25m.5246.150+30.2M07375966+6558511',
#  'apo25m.5246.150+30.2M07380017+6511520',
#  'apo25m.5246.150+30.2M07380622+6522387',
#  'apo25m.5246.150+30.2M07380650+6510464',
#  'apo25m.5246.150+30.2M07381307+6537565',
#  'apo25m.5246.150+30.2M07381469+6530426',
#  'apo25m.5246.150+30.2M07381852+6528162',
#  'apo25m.5246.150+30.2M07382023+6524551',
#  'apo25m.5246.150+30.2M07382294+6507013',
#  'apo25m.5246.150+30.2M07383076+6640064',
#  'apo25m.5246.150+30.2M07383600+6450311',
#  'apo25m.5246.150+30.2M07383861+6601355',
#  'apo25m.5246.150+30.2M07384206+6605493',
#  'apo25m.5246.150+30.2M07385115+6556284',
#  'apo25m.5246.150+30.2M07385596+6630455',
#  'apo25m.5246.150+30.2M07390257+6703009',
#  'apo25m.5246.150+30.2M07391685+6717051',
#  'apo25m.5246.150+30.2M07392614+6514512',
#  'apo25m.5246.150+30.2M07394171+6504207',
#  'apo25m.5246.150+30.2M07394736+6657264',
#  'apo25m.5246.150+30.2M07394934+6626086',
#  'apo25m.5246.150+30.2M07395407+6616425',
#  'apo25m.5246.150+30.2M07400005+6715276',
#  'apo25m.5246.150+30.2M07400104+6603012',
#  'apo25m.5246.150+30.2M07400144+6501504',
#  'apo25m.5246.150+30.2M07401159+6453111',
#  'apo25m.5246.150+30.2M07401654+6532285',
#  'apo25m.5246.150+30.2M07401773+6604370',
#  'apo25m.5246.150+30.2M07403485+6515436',
#  'apo25m.5246.150+30.2M07404341+6630515',
#  'apo25m.5246.150+30.2M07404504+6541145',
#  'apo25m.5246.150+30.2M07405795+6731232',
#  'apo25m.5246.150+30.2M07410421+6708016',
#  'apo25m.5246.150+30.2M07410865+6727134',
#  'apo25m.5246.150+30.2M07411428+6510294',
#  'apo25m.5246.150+30.2M07411681+6515194',
#  'apo25m.5246.150+30.2M07412203+6514031',
#  'apo25m.5246.150+30.2M07412492+6541509',
#  'apo25m.5246.150+30.2M07412525+6538125',
#  'apo25m.5246.150+30.2M07414665+6613416',
#  'apo25m.5246.150+30.2M07414759+6512363',
#  'apo25m.5246.150+30.2M07415257+6607027',
#  'apo25m.5246.150+30.2M07420309+6715410',
#  'apo25m.5246.150+30.2M07421649+6448119',
#  'apo25m.5246.150+30.2M07423554+6634305',
#  'apo25m.5246.150+30.2M07424014+6453363',
#  'apo25m.5246.150+30.2M07424480+6621260',
#  'apo25m.5246.150+30.2M07425897+6553390',
#  'apo25m.5246.150+30.2M07430408+6453368',
#  'apo25m.5246.150+30.2M07430494+6616111',
#  'apo25m.5246.150+30.2M07431347+6613227',
#  'apo25m.5246.150+30.2M07431501+6529554',
#  'apo25m.5246.150+30.2M07431809+6657249',
#  'apo25m.5246.150+30.2M07431994+6653417',
#  'apo25m.5246.150+30.2M07434553+6629100',
#  'apo25m.5246.150+30.2M07434594+6727042',
#  'apo25m.5246.150+30.2M07435348+6540229',
#  'apo25m.5246.150+30.2M07435639+6514519',
#  'apo25m.5246.150+30.2M07441999+6542116',
#  'apo25m.5246.150+30.2M07442547+6633168',
#  'apo25m.5246.150+30.2M07442820+6540561',
#  'apo25m.5246.150+30.2M07443494+6449416',
#  'apo25m.5246.150+30.2M07443623+6523272',
#  'apo25m.5246.150+30.2M07444684+6632173',
#  'apo25m.5246.150+30.2M07444726+6638029',
#  'apo25m.5246.150+30.2M07445416+6541249',
#  'apo25m.5246.150+30.2M07445641+6552264',
#  'apo25m.5246.150+30.2M07450069+6530098',
#  'apo25m.5246.150+30.2M07450946+6653395',
#  'apo25m.5246.150+30.2M07451242+6734339',
#  'apo25m.5246.150+30.2M07454300+6442599',
#  'apo25m.5246.150+30.2M07462239+6635314',
#  'apo25m.5246.150+30.2M07463277+6512543',
#  'apo25m.5246.150+30.2M07463277+6715060',
#  'apo25m.5246.150+30.2M07463471+6632229',
#  'apo25m.5246.150+30.2M07464380+6552496',
#  'apo25m.5246.150+30.2M07470247+6510334',
#  'apo25m.5246.150+30.2M07470929+6518334',
#  'apo25m.5246.150+30.2M07472103+6455204',
#  'apo25m.5246.150+30.2M07472323+6602519',
#  'apo25m.5246.150+30.2M07472470+6648565',
#  'apo25m.5246.150+30.2M07473035+6553540',
#  'apo25m.5246.150+30.2M07475321+6611485',
#  'apo25m.5246.150+30.2M07475737+6653337',
#  'apo25m.5246.150+30.2M07475857+6711394',
#  'apo25m.5246.150+30.2M07482365+6445045',
#  'apo25m.5246.150+30.2M07482525+6615109',
#  'apo25m.5246.150+30.2M07483915+6603222',
#  'apo25m.5246.150+30.2M07484440+6719354',
#  'apo25m.5246.150+30.2M07490451+6656585',
#  'apo25m.5246.150+30.2M07490533+6518360',
#  'apo25m.5246.150+30.2M07490587+6554173',
#  'apo25m.5246.150+30.2M07491581+6519454',
#  'apo25m.5246.150+30.2M07491584+6654523',
#  'apo25m.5246.150+30.2M07492590+6515530',
#  'apo25m.5246.150+30.2M07493448+6725198',
#  'apo25m.5246.150+30.2M07493678+6653436',
#  'apo25m.5246.150+30.2M07493888+6604465',
#  'apo25m.5246.150+30.2M07494477+6454408',
#  'apo25m.5246.150+30.2M07502243+6615325',
#  'apo25m.5246.150+30.2M07503038+6717232',
#  'apo25m.5246.150+30.2M07504559+6636139',
#  'apo25m.5246.150+30.2M07510450+6507047',
#  'apo25m.5246.150+30.2M07510659+6515121',
#  'apo25m.5246.150+30.2M07511498+6459345',
#  'apo25m.5246.150+30.2M07511665+6524498',
#  'apo25m.5246.150+30.2M07512013+6717131',
#  'apo25m.5246.150+30.2M07512113+6529522',
#  'apo25m.5246.150+30.2M07512495+6545524',
#  'apo25m.5246.150+30.2M07512522+6504122',
#  'apo25m.5246.150+30.2M07512756+6456327',
#  'apo25m.5246.150+30.2M07512854+6610363',
#  'apo25m.5246.150+30.2M07512970+6559294',
#  'apo25m.5246.150+30.2M07513366+6520457',
#  'apo25m.5246.150+30.2M07513772+6527221',
#  'apo25m.5246.150+30.2M07513812+6512563',
#  'apo25m.5246.150+30.2M07513966+6514248',
#  'apo25m.5246.150+30.2M07514151+6719168',
#  'apo25m.5246.150+30.2M07514265+6546333',
#  'apo25m.5246.150+30.2M07514792+6641369',
#  'apo25m.5246.150+30.2M07515101+6650538',
#  'apo25m.5246.150+30.2M07515112+6722097',
#  'apo25m.5246.150+30.2M07515486+6706531',
#  'apo25m.5246.150+30.2M07515506+6631496',
#  'apo25m.5246.150+30.2M07515542+6638420',
#  'apo25m.5246.150+30.2M07520028+6704446',
#  'apo25m.5246.150+30.2M07520423+6711374',
#  'apo25m.5246.150+30.2M07520478+6657465',
#  'apo25m.5246.150+30.2M07520558+6637364',
#  'apo25m.5246.150+30.2M07520700+6715313',
#  'apo25m.5246.150+30.2M07520725+6639592',
#  'apo25m.5246.150+30.2M07524335+6550131',
#  'apo25m.5246.150+30.2M07530893+6515539',
#  'apo25m.5246.150+30.2M07531813+6704311',
#  'apo25m.5246.150+30.2M07532390+6524322',
#  'apo25m.5246.150+30.2M07534706+6534433',
#  'apo25m.5246.150+30.2M07540266+6615476',
#  'apo25m.5246.150+30.2M07543415+6609554',
#  'apo25m.5246.150+30.2M07545641+6531540',
#  'apo25m.5246.150+30.2M07551160+6548517',
#  'apo25m.5246.150+30.2M07553801+6602334',
#  'apo25m.5246.150+30.2M07554030+6541301',
#  'apo25m.5246.150+30.2M07554343+6508404',
#  'apo25m.5246.150+30.2M07555284+6653492',
#  'apo25m.5246.150+30.2M07562738+6515227',
#  'apo25m.5246.150+30.2M07563214+6519042',
#  'apo25m.5246.150+30.2M07564895+6649595',
#  'apo25m.5246.150+30.2M07565272+6553162',
#  'apo25m.5246.150+30.2M07565637+6527293',
#  'apo25m.5246.150+30.2M07570210+6637139',
#  'apo25m.5246.150+30.2M07572615+6534155',
#  'apo25m.5246.150+30.2M07574685+6530089',
#  'apo25m.5246.150+30.2M07575942+6614552',
#  'apo25m.5246.150+30.2M07583331+6630176',
#  'apo25m.5246.150+30.2M07584611+6600548',
#  'apo25m.5246.150+30.2M07590920+6556338',
#  'apo25m.5246.150+30.2M07591866+6604377',
#  'apo25m.5127.GD1-1.2M08201834-0012291',
#  'apo25m.5127.GD1-1.2M08202010-0001530',
#  'apo25m.5127.GD1-1.2M08203937+0037105',
#  'apo25m.5127.GD1-1.2M08204319-0000557',
#  'apo25m.5127.GD1-1.2M08210013+0048207',
#  'apo25m.5127.GD1-1.2M08210148+0027321',
#  'apo25m.5127.GD1-1.2M08210400+0030592',
#  'apo25m.5127.GD1-1.2M08210848+0052044',
#  'apo25m.5127.GD1-1.2M08211035-0002136',
#  'apo25m.5127.GD1-1.2M08211258+0054234',
#  'apo25m.5127.GD1-1.2M08212151-0043433',
#  'apo25m.5127.GD1-1.2M08212769+0105483',
#  'apo25m.5127.GD1-1.2M08212869+0057037',
#  'apo25m.5127.GD1-1.2M08213161-0007555',
#  'apo25m.5127.GD1-1.2M08213275+0059283',
#  'apo25m.5127.GD1-1.2M08213740+0028352',
#  'apo25m.5127.GD1-1.2M08214081-0045470',
#  'apo25m.5127.GD1-1.2M08214323+0110313',
#  'apo25m.5127.GD1-1.2M08215981+0054571',
#  'apo25m.5127.GD1-1.2M08220173+0021225',
#  'apo25m.5127.GD1-1.2M08220635+0045057',
#  'apo25m.5127.GD1-1.2M08221000-0019184',
#  'apo25m.5127.GD1-1.2M08221026+0000258',
#  'apo25m.5127.GD1-1.2M08221063+0027306',
#  'apo25m.5127.GD1-1.2M08221610+0005388',
#  'apo25m.5127.GD1-1.2M08221891+0109450',
#  'apo25m.5127.GD1-1.2M08222287-0055326',
#  'apo25m.5127.GD1-1.2M08222650-0039000',
#  'apo25m.5127.GD1-1.2M08222903+0032570',
#  'apo25m.5127.GD1-1.2M08223298-0044389',
#  'apo25m.5127.GD1-1.2M08223388-0032116',
#  'apo25m.5127.GD1-1.2M08223560+0000158',
#  'apo25m.5127.GD1-1.2M08224636+0025564',
#  'apo25m.5127.GD1-1.2M08224654-0043255',
#  'apo25m.5127.GD1-1.2M08225727+0103484',
#  'apo25m.5127.GD1-1.2M08230090-0036453',
#  'apo25m.5127.GD1-1.2M08230093+0112045',
#  'apo25m.5127.GD1-1.2M08230544-0000342',
#  'apo25m.5127.GD1-1.2M08230687-0024585',
#  'apo25m.5127.GD1-1.2M08230804-0102280',
#  'apo25m.5127.GD1-1.2M08230810+0017552',
#  'apo25m.5127.GD1-1.2M08230906-0030074',
#  'apo25m.5127.GD1-1.2M08230985-0057015',
#  'apo25m.5127.GD1-1.2M08231672-0027398',
#  'apo25m.5127.GD1-1.2M08232836+0010284',
#  'apo25m.5127.GD1-1.2M08233303+0024582',
#  'apo25m.5127.GD1-1.2M08233476+0034120',
#  'apo25m.5127.GD1-1.2M08233588+0018318',
#  'apo25m.5127.GD1-1.2M08234068-0033163',
#  'apo25m.5127.GD1-1.2M08234568+0003340',
#  'apo25m.5127.GD1-1.2M08235059-0017168',
#  'apo25m.5127.GD1-1.2M08235438-0110107',
#  'apo25m.5127.GD1-1.2M08235619+0037518',
#  'apo25m.5127.GD1-1.2M08235829-0050001',
#  'apo25m.5127.GD1-1.2M08235834-0012455',
#  'apo25m.5127.GD1-1.2M08235976-0035526',
#  'apo25m.5127.GD1-1.2M08240948+0104500',
#  'apo25m.5127.GD1-1.2M08241316-0009529',
#  'apo25m.5127.GD1-1.2M08241483-0023240',
#  'apo25m.5127.GD1-1.2M08241541-0032151',
#  'apo25m.5127.GD1-1.2M08242049-0006194',
#  'apo25m.5127.GD1-1.2M08242069+0104495',
#  'apo25m.5127.GD1-1.2M08242709+0009153',
#  'apo25m.5127.GD1-1.2M08242943-0039488',
#  'apo25m.5127.GD1-1.2M08242969+0037081',
#  'apo25m.5127.GD1-1.2M08243248-0051496',
#  'apo25m.5127.GD1-1.2M08243351-0048244',
#  'apo25m.5127.GD1-1.2M08244001-0106485',
#  'apo25m.5127.GD1-1.2M08244095+0100046',
#  'apo25m.5127.GD1-1.2M08244311+0118466',
#  'apo25m.5127.GD1-1.2M08244545+0050134',
#  'apo25m.5127.GD1-1.2M08244620+0020512',
#  'apo25m.5127.GD1-1.2M08245511+0108578',
#  'apo25m.5127.GD1-1.2M08250255+0025367',
#  'apo25m.5127.GD1-1.2M08250444-0100276',
#  'apo25m.5127.GD1-1.2M08250446+0100103',
#  'apo25m.5127.GD1-1.2M08251026-0055339',
#  'apo25m.5127.GD1-1.2M08251431+0012371',
#  'apo25m.5127.GD1-1.2M08251654-0045085',
#  'apo25m.5127.GD1-1.2M08252067-0052397',
#  'apo25m.5127.GD1-1.2M08252599+0039327',
#  'apo25m.5127.GD1-1.2M08252679+0025193',
#  'apo25m.5127.GD1-1.2M08252850+0105177',
#  'apo25m.5127.GD1-1.2M08253643+0058020',
#  'apo25m.5127.GD1-1.2M08254950+0019118',
#  'apo25m.5127.GD1-1.2M08255688-0008494',
#  'apo25m.5127.GD1-1.2M08261001-0043351',
#  'apo25m.5127.GD1-1.2M08261160-0048337',
#  'apo25m.5127.GD1-1.2M08262173+0114351',
#  'apo25m.5127.GD1-1.2M08262245-0023442',
#  'apo25m.5127.GD1-1.2M08262858+0009570',
#  'apo25m.5127.GD1-1.2M08263393+0136303',
#  'apo25m.5127.GD1-1.2M08263512-0110151',
#  'apo25m.5127.GD1-1.2M08263799+0052253',
#  'apo25m.5127.GD1-1.2M08264390+0133351',
#  'apo25m.5127.GD1-1.2M08264927+0114246',
#  'apo25m.5127.GD1-1.2M08265197+0031094',
#  'apo25m.5127.GD1-1.2M08265368+0044137',
#  'apo25m.5127.GD1-1.2M08265638+0112423',
#  'apo25m.5127.GD1-1.2M08265766+0122144',
#  'apo25m.5127.GD1-1.2M08270352+0101104',
#  'apo25m.5127.GD1-1.2M08270378+0040038',
#  'apo25m.5127.GD1-1.2M08270535+0031307',
#  'apo25m.5127.GD1-1.2M08271170-0101054',
#  'apo25m.5127.GD1-1.2M08272156+0007414',
#  'apo25m.5127.GD1-1.2M08272781+0035364',
#  'apo25m.5127.GD1-1.2M08272914+0028155',
#  'apo25m.5127.GD1-1.2M08273149+0046388',
#  'apo25m.5127.GD1-1.2M08274155+0103453',
#  'apo25m.5127.GD1-1.2M08274328-0005140',
#  'apo25m.5127.GD1-1.2M08274698+0135010',
#  'apo25m.5127.GD1-1.2M08274945-0103579',
#  'apo25m.5127.GD1-1.2M08275146+0059214',
#  'apo25m.5127.GD1-1.2M08275570+0035418',
#  'apo25m.5127.GD1-1.2M08280324-0105534',
#  'apo25m.5127.GD1-1.2M08280527+0013330',
#  'apo25m.5127.GD1-1.2M08280660+0032134',
#  'apo25m.5127.GD1-1.2M08281032+0059141',
#  'apo25m.5127.GD1-1.2M08281282-0030034',
#  'apo25m.5127.GD1-1.2M08282353-0054184',
#  'apo25m.5127.GD1-1.2M08282833+0019536',
#  'apo25m.5127.GD1-1.2M08283598-0019018',
#  'apo25m.5127.GD1-1.2M08284529+0019215',
#  'apo25m.5127.GD1-1.2M08284974-0019095',
#  'apo25m.5127.GD1-1.2M08284978-0103429',
#  'apo25m.5127.GD1-1.2M08285007-0044019',
#  'apo25m.5127.GD1-1.2M08285062-0107531',
#  'apo25m.5127.GD1-1.2M08285327+0022409',
#  'apo25m.5127.GD1-1.2M08285552+0004397',
#  'apo25m.5127.GD1-1.2M08285575+0039056',
#  'apo25m.5127.GD1-1.2M08290609+0107019',
#  'apo25m.5127.GD1-1.2M08290666+0118401',
#  'apo25m.5127.GD1-1.2M08290669-0026402',
#  'apo25m.5127.GD1-1.2M08290796-0018005',
#  'apo25m.5127.GD1-1.2M08291452-0008314',
#  'apo25m.5127.GD1-1.2M08293069-0028531',
#  'apo25m.5127.GD1-1.2M08293172+0048080',
#  'apo25m.5127.GD1-1.2M08293683-0001092',
#  'apo25m.5127.GD1-1.2M08294018+0011022',
#  'apo25m.5127.GD1-1.2M08294236+0039534',
#  'apo25m.5127.GD1-1.2M08294750+0027042',
#  'apo25m.5127.GD1-1.2M08295405-0007351',
#  'apo25m.5127.GD1-1.2M08295531-0011445',
#  'apo25m.5127.GD1-1.2M08295639-0030107',
#  'apo25m.5127.GD1-1.2M08295673-0045274',
#  'apo25m.5127.GD1-1.2M08300319+0026563',
#  'apo25m.5127.GD1-1.2M08300377-0045247',
#  'apo25m.5127.GD1-1.2M08300445-0009583',
#  'apo25m.5127.GD1-1.2M08300459-0029533',
#  'apo25m.5127.GD1-1.2M08301447+0056334',
#  'apo25m.5127.GD1-1.2M08301687-0018268',
#  'apo25m.5127.GD1-1.2M08302386+0014477',
#  'apo25m.5127.GD1-1.2M08302791+0044041',
#  'apo25m.5127.GD1-1.2M08304050-0042360',
#  'apo25m.5127.GD1-1.2M08305300+0037334',
#  'apo25m.5127.GD1-1.2M08312249-0009150',
#  'apo25m.5127.GD1-1.2M08313306+0010083',
#  'apo25m.5127.GD1-1.2M08313739-0004242',
#  'apo25m.5127.GD1-1.2M08314453+0005572',
#  'apo25m.5115.GD1-2.2M08400300+1134209',
#  'apo25m.5115.GD1-2.2M08404609+1128039',
#  'apo25m.5115.GD1-2.2M08411684+1102554',
#  'apo25m.5115.GD1-2.2M08414133+1051015',
#  'apo25m.5115.GD1-2.2M08420689+1216216',
#  'apo25m.5115.GD1-2.2M08425586+1106212',
#  'apo25m.5115.GD1-2.2M08430778+1249397',
#  'apo25m.5115.GD1-2.2M08430937+1147220',
#  'apo25m.5115.GD1-2.2M08434384+1115443',
#  'apo25m.5115.GD1-2.2M08453446+1223148',
#  'apo25m.5115.GD1-2.2M08455925+1315487',
#  'apo25m.4162.M67.2M08460241+1158395',
#  'apo25m.4162.M67.2M08461031+1211308',
#  'apo25m.5115.GD1-2.2M08462279+1245399',
#  'apo25m.4162.M67.2M08465415+1141566',
#  'apo25m.4162.M67.2M08465521+1159488',
#  'apo25m.4162.M67.2M08465863+1237104',
#  'apo25m.4162.M67.2M08471117+1237586',
#  'apo25m.5115.GD1-2.2M08471174+1311402',
#  'apo25m.5115.GD1-2.2M08471960+1200558',
#  'apo25m.5115.GD1-2.2M08474493+1125002',
#  'apo25m.4162.M67.2M08474493+1125002',
#  'apo25m.4162.M67.2M08474775+1243057',
#  'apo25m.4162.M67.2M08474967+1209048',
#  'apo25m.4162.M67.2M08475131+1147500',
#  'apo25m.4162.M67.2M08480368+1048356',
#  'apo25m.4162.M67.2M08480371+1137211',
#  'apo25m.4162.M67.2M08481310+1121317',
#  'apo25m.5115.GD1-2.2M08481969+1314447',
#  'apo25m.4162.M67.2M08482833+1153288',
#  'apo25m.4162.M67.2M08493387+1210146',
#  'apo25m.4162.M67.2M08494757+1244249',
#  'apo25m.5115.GD1-2.2M08500627+1232397',
#  'apo25m.4162.M67.2M08500627+1232397',
#  'apo25m.4162.M67.2M08501918+1056436',
#  'apo25m.4162.M67.2M08503912+1042340',
#  'apo25m.4162.M67.2M08504952+1217158',
#  'apo25m.5115.GD1-2.2M08505769+1200406',
#  'apo25m.4162.M67.2M08505983+1130493',
#  'apo25m.5115.GD1-2.2M08510076+1153115',
#  'apo25m.5115.GD1-2.2M08510246+1155221',
#  'apo25m.5115.GD1-2.2M08510294+1133254',
#  'apo25m.4162.M67.2M08510723+1153019',
#  'apo25m.5115.GD1-2.2M08510783+1159354',
#  'apo25m.5115.GD1-2.2M08511130+1157212',
#  'apo25m.5115.GD1-2.2M08511176+1150018',
#  'apo25m.5115.GD1-2.2M08511446+1144409',
#  'apo25m.5115.GD1-2.2M08512194+1153089',
#  'apo25m.4162.M67.2M08512202+1304038',
#  'apo25m.5115.GD1-2.2M08512386+1138521',
#  'apo25m.4162.M67.2M08512515+1214495',
#  'apo25m.4162.M67.2M08512530+1202563',
#  'apo25m.5115.GD1-2.2M08512701+1151525',
#  'apo25m.5115.GD1-2.2M08512734+1207406',
#  'apo25m.4162.M67.2M08512734+1207406',
#  'apo25m.5115.GD1-2.2M08512861+1138314',
#  'apo25m.5115.GD1-2.2M08513424+1145535',
#  'apo25m.5115.GD1-2.2M08513431+1151104',
#  'apo25m.5115.GD1-2.2M08513673+1149590',
#  'apo25m.5115.GD1-2.2M08514189+1149376',
#  'apo25m.5115.GD1-2.2M08514632+1200553',
#  'apo25m.5115.GD1-2.2M08514864+1149156',
#  'apo25m.5115.GD1-2.2M08515290+1146358',
#  'apo25m.4162.M67.2M08515586+1109312',
#  'apo25m.5115.GD1-2.2M08515600+1151264',
#  'apo25m.5115.GD1-2.2M08515893+1159560',
#  'apo25m.4162.M67.2M08520253+1207046',
#  'apo25m.4162.M67.2M08521074+1144058',
#  'apo25m.4162.M67.2M08521268+1019336',
#  'apo25m.4162.M67.2M08533445+1209352',
#  'apo25m.4162.M67.2M08540077+1141309',
#  'apo25m.4162.M67.2M08540280+1057052',
#  'apo25m.4162.M67.2M08541894+1239291',
#  'apo25m.4162.M67.2M08543965+1229595',
#  'apo25m.4162.M67.2M08544465+1130053',
#  'apo25m.4162.M67.2M08544578+1218431',
#  'apo25m.4162.M67.2M08545627+1213146',
#  'apo25m.4162.M67.2M08545897+1225409',
#  'apo25m.4162.M67.2M08550676+1047392',
#  'apo25m.4162.M67.2M08554792+1228051',
#  'apo25m.4162.M67.2M08571436+1157587',
#  'apo25m.5116.GD1-3.2M09085051+2213562',
#  'apo25m.5116.GD1-3.2M09090247+2212334',
#  'apo25m.5116.GD1-3.2M09090652+2215497',
#  'apo25m.5116.GD1-3.2M09091212+2218509',
#  'apo25m.5116.GD1-3.2M09091334+2143073',
#  'apo25m.5116.GD1-3.2M09091700+2146192',
#  'apo25m.5116.GD1-3.2M09092060+2212341',
#  'apo25m.5116.GD1-3.2M09092274+2200528',
#  'apo25m.5116.GD1-3.2M09092535+2231104',
#  'apo25m.5116.GD1-3.2M09092614+2211370',
#  'apo25m.5116.GD1-3.2M09092904+2304055',
#  'apo25m.5116.GD1-3.2M09093166+2136250',
#  'apo25m.5116.GD1-3.2M09094831+2249407',
#  'lco25m.5252.270+00.2M09100213-4801228',
#  'apo25m.5116.GD1-3.2M09100398+2123049',
#  'apo25m.5116.GD1-3.2M09100484+2144100',
#  'apo25m.5116.GD1-3.2M09100920+2248013',
#  'apo25m.5116.GD1-3.2M09102856+2213436',
#  'apo25m.5116.GD1-3.2M09102996+2140169',
#  'apo25m.5116.GD1-3.2M09103077+2117145',
#  'apo25m.5116.GD1-3.2M09103309+2231099',
#  'lco25m.5252.270+00.2M09103326-4847431',
#  'apo25m.5116.GD1-3.2M09104200+2248134',
#  'apo25m.5116.GD1-3.2M09104328+2321270',
#  'apo25m.5116.GD1-3.2M09105090+2318073',
#  'apo25m.5116.GD1-3.2M09105343+2221165',
#  'apo25m.5116.GD1-3.2M09105644+2320152',
#  'apo25m.5116.GD1-3.2M09111064+2114032',
#  'apo25m.5116.GD1-3.2M09111180+2142329',
#  'apo25m.5116.GD1-3.2M09111397+2109453',
#  'apo25m.5116.GD1-3.2M09112272+2112330',
#  'apo25m.5116.GD1-3.2M09112375+2225581',
#  'apo25m.5116.GD1-3.2M09112559+2307135',
#  'apo25m.5116.GD1-3.2M09112850+2223427',
#  'lco25m.5252.270+00.2M09113091-4840184',
#  'apo25m.5116.GD1-3.2M09113484+2205084',
#  'apo25m.5116.GD1-3.2M09114753+2329226',
#  'lco25m.5252.270+00.2M09115356-4802098',
#  'apo25m.5116.GD1-3.2M09115654+2118352',
#  'apo25m.5116.GD1-3.2M09120291+2212076',
#  'apo25m.5116.GD1-3.2M09120671+2204543',
#  'apo25m.5116.GD1-3.2M09121406+2248090',
#  'apo25m.5116.GD1-3.2M09121834+2144538',
#  'apo25m.5116.GD1-3.2M09122714+2238120',
#  'apo25m.5116.GD1-3.2M09123313+2205382',
#  'apo25m.5116.GD1-3.2M09123341+2201563',
#  'apo25m.5116.GD1-3.2M09123385+2307513',
#  'apo25m.5116.GD1-3.2M09123502+2116543',
#  'apo25m.5116.GD1-3.2M09124325+2300393',
#  'apo25m.5116.GD1-3.2M09125509+2255055',
#  'apo25m.5116.GD1-3.2M09125683+2115547',
#  'apo25m.5116.GD1-3.2M09125886+2243395',
#  'apo25m.5116.GD1-3.2M09130402+2110597',
#  'apo25m.5116.GD1-3.2M09130726+2146121',
#  'lco25m.5252.270+00.2M09130765-4747313',
#  'apo25m.5116.GD1-3.2M09130817+2337099',
#  'apo25m.5116.GD1-3.2M09130837+2320558',
#  'lco25m.5252.270+00.2M09131290-4744240',
#  'apo25m.5116.GD1-3.2M09131326+2245350',
#  'apo25m.5116.GD1-3.2M09131687+2149590',
#  'apo25m.5116.GD1-3.2M09131792+2151159',
#  'apo25m.5116.GD1-3.2M09131912+2231567',
#  'lco25m.5252.270+00.2M09131947-4743301',
#  'apo25m.5116.GD1-3.2M09133743+2221569',
#  'apo25m.5116.GD1-3.2M09134444+2118128',
#  'apo25m.5116.GD1-3.2M09134755+2344549',
#  'apo25m.5116.GD1-3.2M09134813+2334341',
#  'apo25m.5116.GD1-3.2M09135509+2055246',
#  'apo25m.5116.GD1-3.2M09135530+2141058',
#  'apo25m.5116.GD1-3.2M09135877+2337419',
#  'apo25m.5116.GD1-3.2M09135972+2240483',
#  'apo25m.5116.GD1-3.2M09140627+2347289',
#  'apo25m.5116.GD1-3.2M09140737+2114266',
#  'apo25m.5116.GD1-3.2M09141126+2300404',
#  'apo25m.5116.GD1-3.2M09141745+2347094',
#  'apo25m.5116.GD1-3.2M09143390+2155454',
#  'apo25m.5116.GD1-3.2M09144511+2247260',
#  'apo25m.5116.GD1-3.2M09145472+2309154',
#  'apo25m.5116.GD1-3.2M09145812+2200453',
#  'apo25m.5116.GD1-3.2M09150205+2311380',
#  'apo25m.5116.GD1-3.2M09150297+2103558',
#  'lco25m.5252.270+00.2M09150389-4830135',
#  'lco25m.5252.270+00.2M09150395-4836099',
#  'apo25m.5116.GD1-3.2M09150783+2247251',
#  'apo25m.5116.GD1-3.2M09151299+2300524',
#  'apo25m.5116.GD1-3.2M09151321+2330266',
#  'apo25m.5116.GD1-3.2M09152289+2346119',
#  'lco25m.5252.270+00.2M09152440-4744184',
#  'apo25m.5116.GD1-3.2M09152677+2248289',
#  'lco25m.5252.270+00.2M09152850-4821337',
#  'apo25m.5116.GD1-3.2M09153585+2137233',
#  'apo25m.5116.GD1-3.2M09153632+2212581',
#  'apo25m.5116.GD1-3.2M09153657+2322383',
#  'apo25m.5116.GD1-3.2M09153873+2256552',
#  'apo25m.5116.GD1-3.2M09154661+2345032',
#  'apo25m.5116.GD1-3.2M09154671+2118569',
#  'apo25m.5116.GD1-3.2M09155501+2053460',
#  'lco25m.5252.270+00.2M09155562-4834146',
#  'apo25m.5116.GD1-3.2M09160512+2235052',
#  'apo25m.5116.GD1-3.2M09161048+2151088',
#  'apo25m.5116.GD1-3.2M09162387+2251197',
#  'apo25m.5116.GD1-3.2M09163197+2103297',
#  'apo25m.5116.GD1-3.2M09163277+2244176',
#  'apo25m.5116.GD1-3.2M09163975+2254385',
#  'apo25m.5116.GD1-3.2M09163986+2236148',
#  'lco25m.5252.270+00.2M09164349-4819501',
#  'apo25m.5116.GD1-3.2M09164500+2301124',
#  'apo25m.5116.GD1-3.2M09164528+2336540',
#  'apo25m.5116.GD1-3.2M09165046+2213368',
#  'apo25m.5116.GD1-3.2M09165649+2236556',
#  'apo25m.5116.GD1-3.2M09170125+2202205',
#  'apo25m.5116.GD1-3.2M09170410+2234283',
#  'apo25m.5116.GD1-3.2M09170748+2319294',
#  'apo25m.5116.GD1-3.2M09171172+2232066',
#  'apo25m.5116.GD1-3.2M09171188+2303446',
#  'apo25m.5116.GD1-3.2M09171315+2134096',
#  'apo25m.5116.GD1-3.2M09171449+2251240',
#  'apo25m.5116.GD1-3.2M09172065+2154501',
#  'apo25m.5116.GD1-3.2M09172522+2128434',
#  'apo25m.5116.GD1-3.2M09173156+2206176',
#  'apo25m.5116.GD1-3.2M09173311+2134310',
#  'lco25m.5252.270+00.2M09173979-4817299',
#  'apo25m.5116.GD1-3.2M09174271+2156435',
#  'lco25m.5252.270+00.2M09174444-4820497',
#  'lco25m.5252.270+00.2M09175431-4820509',
#  'apo25m.5116.GD1-3.2M09175788+2126323',
#  'apo25m.5116.GD1-3.2M09180106+2310191',
#  'apo25m.5116.GD1-3.2M09180640+2136577',
#  'apo25m.5116.GD1-3.2M09181677+2152360',
#  'apo25m.5116.GD1-3.2M09181743+2120229',
#  'apo25m.5116.GD1-3.2M09182796+2238354',
#  'apo25m.5116.GD1-3.2M09183225+2231203',
#  'apo25m.5116.GD1-3.2M09183712+2133202',
#  'apo25m.5116.GD1-3.2M09183962+2202188',
#  'apo25m.5116.GD1-3.2M09184145+2128227',
#  'apo25m.5116.GD1-3.2M09184465+2216349',
#  'apo25m.5116.GD1-3.2M09184641+2146171',
#  'apo25m.5116.GD1-3.2M09184931+2148307',
#  'apo25m.5116.GD1-3.2M09190556+2327473',
#  'apo25m.5116.GD1-3.2M09191217+2120185',
#  'apo25m.5116.GD1-3.2M09191932+2244423',
#  'apo25m.5116.GD1-3.2M09192924+2250369',
#  'apo25m.5116.GD1-3.2M09193760+2145354',
#  'apo25m.5116.GD1-3.2M09201002+2144421',
#  'apo25m.5250.ORPHAN-5.2M09201908+4745554',
#  'apo25m.5250.ORPHAN-5.2M09202007+4735099',
#  'apo25m.5116.GD1-3.2M09202059+2150481',
#  'apo25m.5116.GD1-3.2M09202185+2206064',
#  'apo25m.5116.GD1-3.2M09203119+2302026',
#  'apo25m.5116.GD1-3.2M09203262+2246015',
#  'apo25m.5094.200+45.2M09203521+2741245',
#  'apo25m.5250.ORPHAN-5.2M09203569+4810259',
#  'apo25m.5250.ORPHAN-5.2M09203719+4744488',
#  'apo25m.5094.200+45.2M09203881+2750368',
#  'apo25m.5116.GD1-3.2M09204027+2214098',
#  'apo25m.5116.GD1-3.2M09204171+2153368',
#  'apo25m.5116.GD1-3.2M09204465+2223164',
#  'apo25m.5116.GD1-3.2M09205417+2239255',
#  'apo25m.5250.ORPHAN-5.2M09205718+4813290',
#  'apo25m.5250.ORPHAN-5.2M09205963+4724598',
#  'apo25m.5094.200+45.2M09211001+2747186',
#  'apo25m.5094.200+45.2M09211599+2804175',
#  'apo25m.5094.200+45.2M09211664+2721129',
#  'apo25m.5094.200+45.2M09211978+2654523',
#  'apo25m.5094.200+45.2M09212865+2721068',
#  'apo25m.5094.200+45.2M09213084+2657214',
#  'apo25m.5094.200+45.2M09213106+2701321',
#  'apo25m.5250.ORPHAN-5.2M09213988+4753379',
#  'apo25m.5250.ORPHAN-5.2M09214036+4821350',
#  'apo25m.5250.ORPHAN-5.2M09214722+4710410',
#  'apo25m.5250.ORPHAN-5.2M09215642+4821378',
#  'apo25m.5250.ORPHAN-5.2M09215679+4802477',
#  'apo25m.5094.200+45.2M09220089+2742274',
#  'apo25m.5094.200+45.2M09220502+2749451',
#  'apo25m.5094.200+45.2M09220753+2820107',
#  'apo25m.5094.200+45.2M09221149+2729096',
#  'apo25m.5094.200+45.2M09221404+2755253',
#  'apo25m.5094.200+45.2M09221708+2818448',
#  'apo25m.5094.200+45.2M09221806+2733099',
#  'apo25m.5094.200+45.2M09222233+2825253',
#  'apo25m.5094.200+45.2M09222321+2759040',
#  'apo25m.5250.ORPHAN-5.2M09222633+4737345',
#  'apo25m.5250.ORPHAN-5.2M09222854+4759286',
#  ...]

# %%
targets_filtered = []

# %%
for t in all_targets:
    if t not in filtered_targets:
        targets_filtered.append(t)
